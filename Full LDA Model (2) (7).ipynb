# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# !python -m spacy download en_core_web_md
# Out:
# Collecting en-core-web-md==3.1.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.1.0/en_core_web_md-3.1.0-py3-none-any.whl (45.4 MB)
#      |████████████████████████████████| 45.4 MB 44.4 MB/s eta 0:00:01██████████▎                | 21.7 MB 2.4 MB/s eta 0:00:10
# Requirement already satisfied: spacy<3.2.0,>=3.1.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from en-core-web-md==3.1.0) (3.1.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-md==3.1.0) (4.62.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.8 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-md==3.1.0) (8.0.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-md==3.1.0) (2.0.4)
# Requirement already satisfied: numpy>=1.15.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-md==3.1.0) (1.21.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-md==3.1.0) (0.8.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-md==3.1.0) (2.25.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-md==3.1.0) (2.0.5)
# Requirement already satisfied: jinja2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-md==3.1.0) (2.11.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-md==3.1.0) (1.0.5)
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-md==3.1.0) (49.6.0.post20210108)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-md==3.1.0) (0.7.4)
# Requirement already satisfied: packaging>=20.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-md==3.1.0) (20.9)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-md==3.1.0) (3.0.5)
# Requirement already satisfied: pathy>=0.3.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-md==3.1.0) (0.6.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.7 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-md==3.1.0) (3.0.8)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-md==3.1.0) (0.3.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-md==3.1.0) (1.8.2)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-md==3.1.0) (3.7.4.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-md==3.1.0) (2.4.1)
# Requirement already satisfied: zipp>=0.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from catalogue<2.1.0,>=2.0.4->spacy<3.2.0,>=3.1.0->en-core-web-md==3.1.0) (3.4.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from packaging>=20.0->spacy<3.2.0,>=3.1.0->en-core-web-md==3.1.0) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pathy>=0.3.5->spacy<3.2.0,>=3.1.0->en-core-web-md==3.1.0) (5.1.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-md==3.1.0) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-md==3.1.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-md==3.1.0) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-md==3.1.0) (1.26.3)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from typer<0.4.0,>=0.3.0->spacy<3.2.0,>=3.1.0->en-core-web-md==3.1.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jinja2->spacy<3.2.0,>=3.1.0->en-core-web-md==3.1.0) (1.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %%
# !pip install -U spacy
# Out:
# Requirement already satisfied: spacy in /srv/conda/envs/notebook/lib/python3.7/site-packages (3.1.1)
# Requirement already satisfied: thinc<8.1.0,>=8.0.8 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy) (8.0.8)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy) (0.8.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy) (4.62.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy) (1.8.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy) (3.0.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy) (2.0.5)
# Requirement already satisfied: pathy>=0.3.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy) (0.6.0)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy) (3.7.4.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy) (2.4.1)
# Requirement already satisfied: packaging>=20.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy) (20.9)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.7 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy) (3.0.8)
# Requirement already satisfied: jinja2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy) (2.11.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy) (2.25.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy) (2.0.4)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy) (0.3.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy) (0.7.4)
# Requirement already satisfied: numpy>=1.15.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy) (1.21.1)
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.7/site-packages (from spacy) (49.6.0.post20210108)
# Requirement already satisfied: zipp>=0.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from catalogue<2.1.0,>=2.0.4->spacy) (3.4.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from packaging>=20.0->spacy) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pathy>=0.3.5->spacy) (5.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.12.5)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from typer<0.4.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jinja2->spacy) (1.1.1)

# %%
# !pip install -U gensim
# Out:
# Requirement already satisfied: gensim in /srv/conda/envs/notebook/lib/python3.7/site-packages (4.0.1)
# Requirement already satisfied: scipy>=0.18.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from gensim) (1.4.1)
# Requirement already satisfied: numpy>=1.11.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from gensim) (1.21.1)
# Requirement already satisfied: smart-open>=1.8.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from gensim) (5.1.0)

# %%
# !pip install -U pyLDAvis
# Out:
# Requirement already satisfied: pyLDAvis in /srv/conda/envs/notebook/lib/python3.7/site-packages (3.3.1)
# Collecting pandas>=1.2.0
#   Using cached pandas-1.3.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.5 MB)
# Requirement already satisfied: jinja2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pyLDAvis) (2.11.3)
# Requirement already satisfied: future in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pyLDAvis) (0.18.2)
# Requirement already satisfied: funcy in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pyLDAvis) (1.16)
# Requirement already satisfied: gensim in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pyLDAvis) (4.0.1)
# Requirement already satisfied: sklearn in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pyLDAvis) (0.0)
# Requirement already satisfied: scikit-learn in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pyLDAvis) (0.24.2)
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pyLDAvis) (49.6.0.post20210108)
# Requirement already satisfied: joblib in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pyLDAvis) (1.0.1)
# Requirement already satisfied: numexpr in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pyLDAvis) (2.7.3)
# Requirement already satisfied: scipy in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pyLDAvis) (1.4.1)
# Requirement already satisfied: numpy>=1.20.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pyLDAvis) (1.21.1)
# Requirement already satisfied: pytz>=2017.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas>=1.2.0->pyLDAvis) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas>=1.2.0->pyLDAvis) (2.8.1)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=1.2.0->pyLDAvis) (1.15.0)
# Requirement already satisfied: smart-open>=1.8.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from gensim->pyLDAvis) (5.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jinja2->pyLDAvis) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from scikit-learn->pyLDAvis) (2.2.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.5
#     Uninstalling pandas-1.1.5:
#       Successfully uninstalled pandas-1.1.5
# Successfully installed pandas-1.3.1

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /srv/conda/envs/notebook/lib/python3.7/site-packages (3.6.2)
# Requirement already satisfied: regex in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nltk) (2021.8.3)
# Requirement already satisfied: tqdm in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nltk) (4.62.0)
# Requirement already satisfied: joblib in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nltk) (1.0.1)
# Requirement already satisfied: click in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nltk) (7.1.2)

# %%
import pandas as pd

# %%
import numpy as np

# %%
import re

# %%
import string

# %%
import spacy

# %%
import gensim

# %%
from gensim import corpora

# %%
import pyLDAvis

# %%
import pyLDAvis.gensim_models as gensimvis

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
import pandas as pd

import numpy as np

import re
import string
import spacy
import gensim
from gensim import corpora
# libraries for visualization
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
import pyLDAvis.gensim_models as gensimvis
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
review_data= pd.read_csv("Reviews_first1000.csv")
print(review_data.head(2))
print(len(review_data))
print('Unique Products')
print(len(review_data.groupby('ProductId')))
print('Unique Users')
print(len(review_data.groupby('UserId')))
# Out:
#    Unnamed: 0  Id   ProductId          UserId ProfileName  \
# 0         NaN   1  B001E4KFG0  A3SGXH7AUHU8GW  delmartian
# 1         NaN   2  B00813GRG4  A1D87F6ZCVE5NK      dll pa
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 999
# Unique Products
# 207
# Unique Users
# 964
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def clean_text(text ): 
    delete_dict = {sp_character: '' for sp_character in string.punctuation} 
    delete_dict[' '] = ' ' 
    table = str.maketrans(delete_dict)
    text1 = text.translate(table)
    #print('cleaned:'+text1)
    textArr= text1.split()
    text2 = ' '.join([w for w in textArr if ( not w.isdigit() and  ( not w.isdigit() and len(w)>3))]) 
    
    return text2.lower()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import nltk
nltk.download('stopwords') # run this one time
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/scipy/io/matlab/mio5.py:98: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from .mio5_utils import VarReader5
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# review_data.dropna(axis = 0, how ='any',inplace=True) 






review_data['Text'] = review_data['Text'].apply(clean_text)
review_data['Num_words_text'] = review_data['Text'].apply(lambda x:len(str(x).split())) 

print('-------Dataset --------')
print(review_data['Score'].value_counts())
print(len(review_data))
print('-------------------------')
max_review_data_sentence_length  = review_data['Num_words_text'].max()

mask = (review_data['Num_words_text'] < 100) & (review_data['Num_words_text'] >=20)
df_short_reviews = review_data[mask]
df_sampled = df_short_reviews.groupby('Score').apply(lambda x: x.sample(n=100,replace=True)).reset_index(drop = True)

print('No of Short reviews')
print(len(df_short_reviews))



#all_sentences = train_data['text'].tolist() + test_data['text'].tolist()
# Out:
# -------Dataset --------
# 5    642
# 4    138
# 1     98
# 3     75
# 2     46
# Name: Score, dtype: int64
# 999
# -------------------------
# No of Short reviews
# 647
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
# function to remove stopwords
def remove_stopwords(text):
    textArr = text.split(' ')
    rem_text = " ".join([i for i in textArr if i not in stop_words])
    return rem_text

# remove stopwords from the text
df_sampled['Text']=df_sampled['Text'].apply(remove_stopwords)
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
nlp = spacy.load('en_core_web_md', disable=['parser', 'ner'])

def lemmatization(texts,allowed_postags=['NOUN', 'ADJ']): 
       output = []
       for sent in texts:
             doc = nlp(sent) 
             output.append([token.lemma_ for token in doc if token.pos_ in allowed_postags ])
       return output
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
text_list=df_sampled['Text'].tolist()
print(text_list[1])
tokenized_reviews = lemmatization(text_list)
print(tokenized_reviews[1])
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# imagine taking kids playground chalk perhaps colored grinding powder plenty chunks scoop mouthbr thats disgusting isbr idea rating flavorful none done nutritional coaching years watched healthy foods progress painfully barely edible excellentbr neanderthalera gluten free want local grocery store take boxes shelf hide different part store perhaps theres trash compactor protect people experience daughter productbr save money ridiculously expensive spend anything elsebr enjoy life bars better putting garbage mouth
# ['kid', 'playground', 'powder', 'plenty', 'chunk', 'mouthbr', 'disgusting', 'isbr', 'idea', 'rating', 'flavorful', 'none', 'nutritional', 'coaching', 'year', 'healthy', 'food', 'edible', 'excellentbr', 'neanderthalera', 'gluten', 'free', 'local', 'grocery', 'store', 'box', 'shelf', 'different', 'part', 'store', 'trash', 'compactor', 'people', 'daughter', 'productbr', 'money', 'expensive', 'elsebr', 'life', 'bar', 'garbage', 'mouth']

# %%
dictionary = corpora.Dictionary(tokenized_reviews)
doc_term_matrix = [dictionary.doc2bow(rev) for rev in tokenized_reviews]
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Creating the object for LDA model using gensim library
LDA = gensim.models.ldamodel.LdaModel

# Build LDA model
lda_model = LDA(corpus=doc_term_matrix, id2word=dictionary, num_topics=10, random_state=100,
                chunksize=1000, passes=50,iterations=100)
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
lda_model.print_topics()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [(0,
#   '0.023*"brand" + 0.022*"chip" + 0.021*"good" + 0.019*"item" + 0.019*"dollar" + 0.016*"great" + 0.016*"kettle" + 0.014*"product" + 0.014*"local" + 0.014*"banana"'),
#  (1,
#   '0.039*"good" + 0.019*"flavor" + 0.016*"date" + 0.016*"food" + 0.015*"sugar" + 0.012*"little" + 0.012*"variety" + 0.012*"seed" + 0.011*"thing" + 0.011*"product"'),
#  (2,
#   '0.035*"ingredient" + 0.026*"product" + 0.017*"food" + 0.016*"quality" + 0.014*"cheap" + 0.012*"brand" + 0.012*"shipment" + 0.012*"life" + 0.011*"peanut" + 0.010*"price"'),
#  (3,
#   '0.026*"plastic" + 0.023*"product" + 0.021*"food" + 0.018*"chip" + 0.016*"flavor" + 0.015*"earth" + 0.015*"taste" + 0.015*"brand" + 0.013*"organic" + 0.012*"good"'),
#  (4,
#   '0.070*"chip" + 0.033*"flavor" + 0.027*"taste" + 0.023*"good" + 0.017*"salt" + 0.015*"vinegar" + 0.014*"potato" + 0.011*"food" + 0.010*"sour" + 0.010*"daughter"'),
#  (5,
#   '0.035*"chip" + 0.022*"coffee" + 0.022*"kettle" + 0.016*"potato" + 0.015*"water" + 0.014*"food" + 0.014*"teabag" + 0.012*"star" + 0.012*"salty" + 0.012*"little"'),
#  (6,
#   '0.083*"chip" + 0.036*"bag" + 0.032*"flavor" + 0.031*"kettle" + 0.028*"hole" + 0.020*"good" + 0.017*"star" + 0.011*"size" + 0.011*"time" + 0.010*"many"'),
#  (7,
#   '0.024*"product" + 0.018*"time" + 0.017*"snack" + 0.016*"people" + 0.015*"energy" + 0.014*"drink" + 0.011*"picture" + 0.011*"open" + 0.010*"bag" + 0.010*"organic"'),
#  (8,
#   '0.028*"juice" + 0.025*"product" + 0.021*"good" + 0.017*"time" + 0.014*"price" + 0.013*"love" + 0.013*"taste" + 0.012*"acai" + 0.012*"flavor" + 0.011*"food"'),
#  (9,
#   '0.030*"stuff" + 0.021*"time" + 0.013*"brand" + 0.012*"great" + 0.012*"right" + 0.012*"pineapple" + 0.011*"whole" + 0.010*"water" + 0.010*"good" + 0.009*"case"')]

# %%
pyLDAvis.enable_notebook()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Visualize the topics
#https://github.com/bmabey/pyLDAvis
#https://speakerdeck.com/bmabey/visualizing-topic-models
pyLDAvis.enable_notebook()
vis = gensimvis.prepare(lda_model, doc_term_matrix, dictionary)
vis
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 4     -0.119854  0.106298       1        1  16.217951
# 6     -0.216578 -0.037374       2        1  14.338932
# 2      0.058076  0.156674       3        1  11.982077
# 8      0.066837  0.067632       4        1  11.584343
# 3      0.044268  0.004408       5        1  11.427859
# 1      0.074358  0.070606       6        1   9.357820
# 5     -0.096179 -0.058605       7        1   7.360259
# 7      0.030183 -0.135572       8        1   6.584830
# 9      0.167743 -0.099120       9        1   6.097659
# 0     -0.008853 -0.074948      10        1   5.048270, topic_info=           Term        Freq       Total Category  logprob  loglift
# 143        chip  304.000000  304.000000  Default  30.0000  30.0000
# 155        hole   41.000000   41.000000  Default  29.0000  29.0000
# 128      kettle   91.000000   91.000000  Default  28.0000  28.0000
# 214       juice   33.000000   33.000000  Default  27.0000  27.0000
# 127  ingredient   62.000000   62.000000  Default  26.0000  26.0000
# ..          ...         ...         ...      ...      ...      ...
# 21         food    3.992737  112.008014  Topic10  -4.8459  -0.3480
# 122        time    3.357473   84.080180  Topic10  -5.0192  -0.2345
# 243      bottom    3.209880   18.029916  Topic10  -5.0642   1.2603
# 506        much    3.209874   22.835948  Topic10  -5.0642   1.0240
# 25      grocery    3.209867   25.659640  Topic10  -5.0642   0.9074
#
# [648 rows x 6 columns], token_table=      Topic      Freq      Term
# term
# 404       7  0.896739      50th
# 200       4  0.950111      acai
# 630       1  0.506955    actual
# 630       2  0.217266    actual
# 630      10  0.217266    actual
# ...     ...       ...       ...
# 600       1  0.444782     yucky
# 600       9  0.444782     yucky
# 611       2  0.945561      zapp
# 294       5  0.866115      zest
# 629       8  0.909829  zucchini
#
# [1119 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[5, 7, 3, 9, 4, 2, 6, 8, 10, 1])

# %%
print('\nPerplexity: ', lda_model.log_perplexity(doc_term_matrix,total_docs=10000))  # a measure of how good the model is. lower the better.

# Compute Coherence Score
from gensim.models.coherencemodel import CoherenceModel
coherence_model_lda = CoherenceModel(model=lda_model, texts=tokenized_reviews, dictionary=dictionary , coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Perplexity:  -5.9153972482627175
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Coherence Score:  0.3456108765741045

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3):
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = gensim.models.ldamodel.LdaModel(corpus=corpus, num_topics=num_topics, id2word=dictionary)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
model_list, coherence_values = compute_coherence_values(dictionary=dictionary, corpus=doc_term_matrix, texts=tokenized_reviews, start=2, limit=50, step=1)
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-c5acd90f22aa> in <module>
# ----> 1 model_list, coherence_values = compute_coherence_values(dictionary=dictionary, corpus=doc_term_matrix, texts=tokenized_reviews, start=2, limit=50, step=1)
#
# <ipython-input-35-ca22a2a97c3b> in compute_coherence_values(dictionary, corpus, texts, limit, start, step)
#      20         model = gensim.models.ldamodel.LdaModel(corpus=corpus, num_topics=num_topics, id2word=dictionary)
#      21         model_list.append(model)
# ---> 22         coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
#      23         coherence_values.append(coherencemodel.get_coherence())
#      24
#
# NameError: name 'CoherenceModel' is not defined

# %%
# Show graph
limit=50; start=2; step=1;
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()# Print the coherence scores
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-b93e4b688b44> in <module>
#       2 limit=50; start=2; step=1;
#       3 x = range(start, limit, step)
# ----> 4 plt.plot(x, coherence_values)
#       5 plt.xlabel("Num Topics")
#       6 plt.ylabel("Coherence score")
#
# NameError: name 'coherence_values' is not defined

# %%
# Print the coherence scores
for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 4))
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-374779cc73b5> in <module>
#       1 # Print the coherence scores
# ----> 2 for m, cv in zip(x, coherence_values):
#       3     print("Num Topics =", m, " has Coherence Value of", round(cv, 4))
#
# NameError: name 'x' is not defined

# %%
# Select the model and print the topics
optimal_model = model_list[39]
model_topics = optimal_model.show_topics(formatted=False)
optimal_model.print_topics(num_words=10)
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-8a4d6cc7ef6a> in <module>
#       1 # Select the model and print the topics
# ----> 2 optimal_model = model_list[39]
#       3 model_topics = optimal_model.show_topics(formatted=False)
#       4 optimal_model.print_topics(num_words=10)
#
# NameError: name 'model_list' is not defined

# %%
pyLDAvis.enable_notebook()
vis = gensimvis.prepare(optimal_model, doc_term_matrix, dictionary)
vis
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-da878799e6e0> in <module>
#       1 pyLDAvis.enable_notebook()
# ----> 2 vis = gensimvis.prepare(optimal_model, doc_term_matrix, dictionary)
#       3 vis
#
# NameError: name 'optimal_model' is not defined
